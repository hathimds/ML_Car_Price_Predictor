# %% [markdown]
# ## Libraries

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
import pickle

# %% [markdown]
# First, we should call some variables from data cleaning process.

# %%
# %store -r df
df = df

# %store -r numeric_columns
numeric_columns = numeric_columns

# %% [markdown]
# ## Handle Outlier
#
# ### Outlier Detection
#
# First, let's see the box plot to see the status of data.

# %%
def box_plot(columns):
    fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 6))
    axes = axes.flatten()

    for i, col in enumerate(columns):
        sns.boxplot(x=df[col], ax=axes[i])
        axes[i].set_title(f'{col}')

    plt.tight_layout
    plt.show()

# Example usage:
box_plot(numeric_columns[:6])

# %% [markdown]
# ## Categorical Encoding
#
# ### Mean-Target Encoding
#
# Since Brand and Model have many unique values (high cardinality), we use Mean Target encoding for them.
#
# - Calculate the Mean Target (Price) for Each category.
# - Replace category in with its corresponding Mean Price.

# %%
# Brand
brand_mean_price = df.groupby('Brand')['Price'].mean()
df['Encoded_Brand'] = df['Brand'].map(brand_mean_price)

# Model
model_mean_price = df.groupby('Model')['Price'].mean()
df['Encoded_Model'] = df['Model'].map(model_mean_price)

# Drop
df.drop(['Brand', 'Model'], axis=1, inplace=True)

# %%
df.head()
# Out:
#       Year  EngineSize      Fuel    Transmission  Mileage  Doors  OwnerCount  \
# 9254  2007         3.2    Hybrid  Semi-Automatic    33948      5           4
# 1561  2010         4.8  Electric  Semi-Automatic   224853      2           1
# 1670  2006         1.9    Hybrid  Semi-Automatic    13435      3           5
# 6087  2019         1.7    Diesel  Semi-Automatic   199846      2           3
# 6669  2005         3.6    Petrol       Automatic      261      3           2
#
#       Price  Encoded_Brand  Encoded_Model
# 9254   9721    8901.128019    8782.205323
# 1561   9402    8650.208122    8604.644689
# 1670   8531    8780.323961    8729.062044
# 6087   7503    8585.052045    8640.753036
# 6669  10694    8892.547554    8934.714859

# %% [markdown]
# Now, we should save it for future usage

# %%
with open('C:/Users/user/Documents/DATA SCIENCE/Projects/CAR PRICE PREDICTION/models/Brand_Encoder.pkl', 'wb') as f:
    pickle.dump(brand_mean_price, f)

with open('C:/Users/user/Documents/DATA SCIENCE/Projects/CAR PRICE PREDICTION/models/Model_Encoder.pkl', 'wb') as f:
    pickle.dump(model_mean_price, f)

# %% [markdown]
# ### One-Hot Encoding
#
# Now, for Transmission and Fuel, just because they don't have too many cardinality, we can use one-hot encoding.

# %%
# Select categorical columns to encode
categorical_cols = ['Fuel', 'Transmission']

# Define OneHotEncoder
encoder = OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore')

# Fit and transform only selected categorical columns
encoded_array = encoder.fit_transform(df[categorical_cols])

# Convert to DataFrame
encoded_df = pd.DataFrame(encoded_array, columns=encoder.get_feature_names_out(categorical_cols))

# Drop original categorical columns and merge encoded ones
df_encoded = df.drop(columns=categorical_cols).reset_index(drop=True)
df = pd.concat([df_encoded, encoded_df], axis=1)

# %% [markdown]
# Now, we should save encoder for test and unseen data

# %%
with open('C:/Users/user/Documents/DATA SCIENCE/Projects/CAR PRICE PREDICTION/models/OneHot_Encoder.pkl', 'wb') as f:
    pickle.dump(encoder, f)

# %% [markdown]
# ## CHECKPOINT

# %%
# %store df
# Out:
# Stored 'df' (DataFrame)
